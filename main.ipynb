# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):

    if a > b:
        return (a)
    else:
        return (b)

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.063s
#
# OK

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
def greatest(arr):

    i = arr[ 0 ]
    for a in arr:
        if a > i:
            i = a
    return i

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.050s
#
# OK

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(arr):
    pass

    suma = 0
    for i in arr:
        suma = suma + i
    return suma

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.052s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(arr):
    pass

    total = 1
    for i in arr:
        total = total*i
    return total

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.048s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
# Sigo sin verlo!! 😭

def oper_all(arr, oper):

    suma = 0
    total = 1
    
    if oper == "+":
        
        for i in arr:
            suma = suma + i
            return suma
    else:
        for i in arr:
            total = total*i
            return total

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF.FF
# ...
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/angela/Desktop/Ironhack/Week1/Lab4/lab-functions/mod/testing.py", line 78, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: -1 != 0 : Should be 0
#
# ...
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/angela/Desktop/Ironhack/Week1/Lab4/lab-functions/mod/testing.py", line 78, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 10 != -8 : Should be -8
#
# ...
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown)
# ...

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    pass

    if n == 0:
        return 1
    else:
        return n * factorial(n-1)

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.051s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(arr):
    pass

    x = []
    for a in arr:
        if a not in x:
            x.append(a)
    return x

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.149s
#
# OK

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
    
    maximum = 0
    for num in arr:
        count = arr[num]
    if count > maximum:
        maximum = count
    if count == maximum:
        return num

# %%
# This will test your function 
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.105s
#
# OK

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
#Visto en clase con Felipe, tengo que darle una vuelta para entender sus
# diferencias con el mío

from statistics import stdev

'''def mean (arr):
    suma = 0
    for n in arr:
        suma += i
        return (suma / len (arr))
        
def st_dev(arr,mean):
    
    suma = 0
    for i in arr:
        suma += ( i - mean) ** 2
        
    operacion = suma / (len (arr) - 1)
    
    st_dev = operacion ** 1/2
    
    return (st_dev)'''

def st_dev(arr):
    suma = 0
    n = 0
    for num in arr:
        suma += num
        n += 1
    avg = suma/n
    stdev = 0
    for num in arr:
        stdev += (num-avg)**2
    stdev /= n-1
    stdev **=.5
    return stdev

# %%
# This will test your function 
test_stdev(st_dev)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.062s
#
# OK

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
# No sé cómo sacarlo

def pangram(string):
    
    alphabet = "abcdefghijklmnopqrstuvwxyz"
    
    for letter in alphabet: 
        if letter in string: 
            return True
    return False

# %%
# This will test your function 
test_pangram(pangram)
# Out:
# ...............FFFFFFFFFFFFFFF
# ...
# FAIL: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/angela/Desktop/Ironhack/Week1/Lab4/lab-functions/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ...
# FAIL: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/angela/Desktop/Ironhack/Week1/Lab4/lab-functions/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ...
# FAIL: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# ...

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
    pass

# %%
# This will test your function 
test_alpha(sort_alpha)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ...
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/angela/Desktop/Ironhack/Week1/Lab4/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 'aylwsoaimm,dyvievvluh,hmzl,jxwoq,kmxckpu[69 chars]xqok' : Should be aylwsoaimm,dyvievvluh,hmzl,jxwoq,kmxckpu,kpizneir,lbrt,llvubpnw,pbyacgml,rfeo,rlvc,vjppfz,xhatc,xhtumotxku,zgxqok
#
# ...
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/angela/Desktop/Ironhack/Week1/Lab4/lab-functions/mod/testing.py", line 187, in runTest
# ...

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.
# `Valid special characters: # @ ! $ % & ( ) ^ * [ ] { }`

# %%
#Visto en clase con Felipe, tengo que darle una vuelta para entenderlo bien


def at_least (password, n=8):
    count = 0
    for i in password:
        count +=1
    return count >= n

def contains (password, arr):
    for i in password:
        for j in arr:
            if i == j:
                return True
    return False

def check_pass(string):
    if not at_least(string):
        return False
    if not contains (string,"abcdefghijklmnopqrstuvwxyz"):
        return False
    if not contains (string,"ABCDEFGHIJKLMNOPQRSTUVWXYZ"):
        return False
    if not contains (string,"0123456789"):
        return False
    if not contains (string,"#@!$%&()^*[]{}"):
        return False
    return True

# %%
# This will test your function 
test_pass(check_pass)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.069s
#
# OK
